# %%
# IMPORT LIBRARIES
import numpy as np
import pandas as pd
# LOAD THE CSV FILES
d1=pd.read_csv("2015.csv")
d2=pd.read_csv("2016.csv")
d3=pd.read_csv("2017.csv")
d4=pd.read_csv("2018.csv")
d5=pd.read_csv("2019.csv")
# RETRIEVE THE COLUMN
happiness_score_list_2015=[]
column1 = "Health (Life Expectancy)"
# RANGED VALUES
min = 0.5
max = 1
# RANGED VALUES
values = d1[(d1[column1] >= min) & (d1[column1] <= max)][column1].tolist()
print("\n\n The values that range from 0.5 to 1 from Health (Life Expectancy): \n\n ")
print(values)
list1 = []
column_values = d2["Happiness Score"].tolist()
for i in range(10):
    maxi = d2["Happiness Score"].max()
    list1.append(maxi)
    d2 = d2[d2["Happiness Score"] < maxi]

print("\n\nThe Happiness Score of top 10 countries: \n\n")
print(list1)

print("\n\n")
# MEAN VALUE FROM A DATA SET
###############################################################
print("THE MEAN VALUES OF THE HAPPINESS SCORED OF COUNTRIES GROUPED IN REGIONS OF YEAR 2016: \n\n")
list2=d2.loc[d2['Region']=='Western Europe', 'Country'].tolist()
print(list2)
print("---------------------------------------------------")
print('               Western Europe                     \n')
Grouped_1_mean=  d2.loc[d2['Country'].isin(list2),['Country', 'Happiness Score']]
print(Grouped_1_mean.mean())

list3=d2.loc[d2['Region']=='North America', 'Country'].tolist()
print(list3)
print("---------------------------------------------------")
print('                 North America                   \n')
Grouped_2_mean=  d2.loc[d2['Country'].isin(list3),['Country', 'Happiness Score']]
print(Grouped_2_mean.mean())
print("---------------------------------------------------")
list4 = d2.loc[d2['Region'] == 'Australia and New Zealand', 'Country'].tolist()
#print(list4)
print('           Australia and New Zealand          \n')
Grouped_3_mean = d2.loc[d2['Country'].isin(list4), ['Country', 'Happiness Score']]
print(Grouped_3_mean['Happiness Score'].mean())
print("---------------------------------------------------")
list5=d2.loc[d2['Region']=='Middle East and Northern Africa', 'Country'].tolist()
#print(list5)
print('         Middle East and Northern Africa          \n')
Grouped_4_mean=  d2.loc[d2['Country'].isin(list5),['Country', 'Happiness Score']]
print(Grouped_4_mean.mean())
print("-----------------------------------------------------")
list6=d2.loc[d2['Region']=='Southeastern Asia', 'Country'].tolist()
#print(list6)
print("              Southeastern Asia               \n")
Grouped_5_mean=  d2.loc[d2['Country'].isin(list6),['Country', 'Happiness Score']]
print(Grouped_5_mean.mean())
print("-----------------------------------------------------")
list7=d2.loc[d2['Region']=='Latin America and Caribbean', 'Country'].tolist()
#print(list7)
print("          Latin America and Caribbean               \n")
Grouped_6_mean=  d2.loc[d2['Country'].isin(list7),['Country', 'Happiness Score']]
print(Grouped_6_mean.mean())
print("-----------------------------------------------------")
list8=d2.loc[d2['Region']=='', 'Country'].tolist()
#print(list8)
print("                  Eastern Asia                       \n")
Grouped_7_mean=  d2.loc[d2['Country'].isin(list8),['Country', 'Happiness Score']]
print(Grouped_7_mean.mean())
print("-----------------------------------------------------")
list9=d2.loc[d2['Region']=='Central and Eastern Europe', 'Country'].tolist()
#print(list9)
print("              Central and Eastern Europe           \n")
Grouped_8_mean=  d2.loc[d2['Country'].isin(list9),['Country', 'Happiness Score']]
print(Grouped_8_mean.mean())
print("-----------------------------------------------------")
list10=d2.loc[d2['Region']=='Sub-Saharan Africa', 'Country'].tolist()
#print(list10)
print("                  Sub-Saharan Africa               \n")
Grouped_9_mean=  d2.loc[d2['Country'].isin(list10),['Country', 'Happiness Score']]
print(Grouped_9_mean.mean())
print("-----------------------------------------------------")

#########################################################################################OUTLIERS############################################################################
print("                 CHECKING FOR OUTLIERS in Happiness Rank 2015                   ")
happiness_ranks_list_2015=d1["Happiness Rank"].tolist()
#print(list100)
Q1=np.percentile(happiness_ranks_list_2015,25)
print("The Q1 for happiness rank in 2015 is: ", Q1)
Q3=np.percentile(happiness_ranks_list_2015,75)
print("The Q1 for happiness rank in 2015 is: ", Q3)
IQR=Q3-Q1
print("The IQR for happiness rank in 2015 is: ", IQR)
lower_bound=Q1-1.5*IQR
print("The lower bound is: ", lower_bound)
upper_bound=Q3+1.5*IQR
print("The upper bound is: ", upper_bound)
print(f"The values that lie below {lower_bound} and above {upper_bound} are outliers")
outliers_in_happiness_rank_2015 = []
for i in happiness_score_list_2015:
    if (i < lower_bound) or (i > upper_bound):
        outliers_in_happiness_rank_2015.append(i)

if len(outliers_in_happiness_rank_2015) == 0:
    print("No outlier found!!")
print("-------------------------------------------------------------------------------")
print("                 CHECKING FOR OUTLIERS in Happiness Score 2015                   ")
happiness_score_list_2015=d1["Happiness Score"].tolist()
Q1=np.percentile(happiness_score_list_2015,25)
Q3=np.percentile(happiness_score_list_2015,75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outliers_in_happiness_score_2015 = []
for i in happiness_score_list_2015:
    if (i < lower_bound) or (i > upper_bound):
        outliers_in_happiness_score_2015.append(i)

if len(outliers_in_happiness_score_2015) == 0:
    print("No outlier found!!")

print("-------------------------------------------------------------------------------")
print("                 CHECKING FOR OUTLIERS in Standard Error 2015                   ")
standard_errors_list_2015=d1["Standard Error"].tolist()
#print(list100)
Q1=np.percentile(standard_errors_list_2015,25)
Q3=np.percentile(standard_errors_list_2015,75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outliers_in_standard_errors_2015 = []
for i in standard_errors_list_2015:
    if (i < lower_bound) or (i > upper_bound):
        outliers_in_standard_errors_2015.append(i)

if len(outliers_in_standard_errors_2015) == 0:
    print("No outlier found!!")
else:
    for i in outliers_in_standard_errors_2015:
        print(i)

print("-------------------------------------------------------------------------------")
print("             CHECKING FOR OUTLIERS in_family_2015              ")
import numpy as np

family_list_2015 = d1["Family"].tolist()

Q1 = np.percentile(family_list_2015, 25)

Q3 = np.percentile(family_list_2015, 75)

IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_family_2015 = []
for i in family_list_2015:
    if i < lower_bound or i > upper_bound:
        outliers_in_family_2015.append(i)

if len(outliers_in_family_2015) == 0:
    print("No outliers found!!")
else:
    print("Outliers in the 'Family' column for 2015:")
    for i in outliers_in_family_2015:
        print(i)
print("-------------------------------------------------------------------------------")
print("             CHECKING FOR OUTLIERS IN HEALTH ( LIFE EXPECTANCY )               ")
import numpy as np

print("Checking for Outliers in Health (Life Expectancy)")
health_list_2015 = d1["Health (Life Expectancy)"].tolist()

Q1 = np.percentile(health_list_2015, 25)

Q3 = np.percentile(health_list_2015, 75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR

upper_bound = Q3 + 1.5 * IQR

outliers_in_health_2015 = []
for i in health_list_2015:
    if i < lower_bound or i > upper_bound:
        outliers_in_health_2015.append(i)

if len(outliers_in_health_2015) == 0:
    print("No outliers found!!")
else:
    print("Outliers in the 'Health (Life Expectancy)' column for 2015:")
    for i in outliers_in_health_2015:
        print(i)

print("-------------------------------------------------------------------------------")

print("                                Checking for Outliers in Freedom")
freedom_list_2015 = d1["Freedom"].tolist()

Q1 = np.percentile(freedom_list_2015, 25)

Q3 = np.percentile(freedom_list_2015, 75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR

upper_bound = Q3 + 1.5 * IQR

outliers_in_freedom_2015 = []
for i in freedom_list_2015:
    if i < lower_bound or i > upper_bound:
        outliers_in_freedom_2015.append(i)

if len(outliers_in_freedom_2015) == 0:
    print("No outliers found!!")
else:
    print("Outliers in the 'Freedom' column for 2015:")
    for i in outliers_in_freedom_2015:
        print(i)

print("-------------------------------------------------------------------------------")

print("Checking for Outliers in Generosity in 2015")
generosity_list_2015 = d1["Generosity"].tolist()

Q1 = np.percentile(generosity_list_2015, 25)

Q3 = np.percentile(generosity_list_2015, 75)


IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR

upper_bound = Q3 + 1.5 * IQR

outliers_in_generosity_2015 = []
for i in generosity_list_2015:
    if i < lower_bound or i > upper_bound:
        outliers_in_generosity_2015.append(i)

if len(outliers_in_generosity_2015) == 0:
    print("No outliers found!!")
else:
    print("Outliers in the 'Generosity' column for 2015:")
    for i in outliers_in_generosity_2015:
        print(i)
print("-------------------------------------------------------------------------------")

print("                 CHECKING FOR OUTLIERS in DYSTOPIA RESIDUAL in 2015                   ")


print("Checking for Outliers in Dystopia Residual in 2015")
Dystopia_Residual_list_2015 = d1["Dystopia Residual"].tolist()

Q1 = np.percentile(Dystopia_Residual_list_2015, 25)

Q3 = np.percentile(Dystopia_Residual_list_2015, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR

upper_bound = Q3 + 1.5 * IQR
outliers_in_dystopia_residual_2015 = []
for i in Dystopia_Residual_list_2015:
    if i < lower_bound or i > upper_bound:
        outliers_in_dystopia_residual_2015.append(i)

if len(outliers_in_dystopia_residual_2015) == 0:
    print("No outliers found!!")
else:
    print("Outliers in the 'Dystopia Residual' column for 2015:")
    for i in outliers_in_dystopia_residual_2015:
        print(i)
####################################################################################2016#########################################################################
print(" \n\n                                                                       OUTLIERS IN 2016                                                        \n\n   ")
import numpy as np

print("Checking for Outliers in Health (Life Expectancy) for 2016")
health_list_2016 = d2["Health (Life Expectancy)"].tolist()

Q1 = np.percentile(health_list_2016, 25)
#print("The first quartile (Q1) for Health (Life Expectancy) in 2016 is:", Q1)

Q3 = np.percentile(health_list_2016, 75)
#print("The third quartile (Q3) for Health (Life Expectancy) in 2016 is:", Q3)

IQR = Q3 - Q1
#print("The Interquartile Range (IQR) for Health (Life Expectancy) in 2016 is:", IQR)

lower_bound = Q1 - 1.5 * IQR
#print("The lower bound for potential outliers is:", lower_bound)

upper_bound = Q3 + 1.5 * IQR
#print("The upper bound for potential outliers is:", upper_bound)

#print(f"The values that lie below {lower_bound} and above {upper_bound} are considered outliers")

outliers_in_health_2016 = []
for i in health_list_2016:
    if i < lower_bound or i > upper_bound:
        outliers_in_health_2016.append(i)

if len(outliers_in_health_2016) == 0:
    print("                                           No outliers found!!")
else:
    print("Outliers in the 'Health (Life Expectancy)' column for 2016:")
    for i in outliers_in_health_2016:
        print(i)
import numpy as np

# Checking for Outliers in Happiness Rank 2016
happiness_ranks_list_2016 = d2["Happiness Rank"].tolist()
Q1 = np.percentile(happiness_ranks_list_2016, 25)
Q3 = np.percentile(happiness_ranks_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_happiness_rank_2016 = [i for i in happiness_ranks_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Happiness Rank' for 2016:")
if len(outliers_in_happiness_rank_2016) == 0:
    print("                                           No outliers found!!")
else:
    for i in outliers_in_happiness_rank_2016:
        print(i)

# Checking for Outliers in Happiness Score 2016
happiness_score_list_2016 = d2["Happiness Score"].tolist()
Q1 = np.percentile(happiness_score_list_2016, 25)
Q3 = np.percentile(happiness_score_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_happiness_score_2016 = [i for i in happiness_score_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Happiness Score' for 2016:")
if len(outliers_in_happiness_score_2016) == 0:
    print("                                            No outliers found!!")
else:
    for i in outliers_in_happiness_score_2016:
        print(i)

# Checking for Outliers in Economy (GDP per Capita) 2016
economy_list_2016 = d2["Economy (GDP per Capita)"].tolist()
Q1 = np.percentile(economy_list_2016, 25)
Q3 = np.percentile(economy_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_economy_2016 = [i for i in economy_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Economy (GDP per Capita)' for 2016:")
if len(outliers_in_economy_2016) == 0:
    print("                                            No outliers found!!")
else:
    for i in outliers_in_economy_2016:
        print(i)

# Continue this pattern for the other columns...
import numpy as np

# Checking for Outliers in Family 2016
family_list_2016 = d2["Family"].tolist()
Q1 = np.percentile(family_list_2016, 25)
Q3 = np.percentile(family_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_family_2016 = [i for i in family_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Family' for 2016:")
if len(outliers_in_family_2016) == 0:
    print("                                              No outliers found!!")
else:
    for i in outliers_in_family_2016:
        print(i)

# Checking for Outliers in Freedom 2016
freedom_list_2016 = d2["Freedom"].tolist()
Q1 = np.percentile(freedom_list_2016, 25)
Q3 = np.percentile(freedom_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_freedom_2016 = [i for i in freedom_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Freedom' for 2016:")
if len(outliers_in_freedom_2016) == 0:
    print("                                              No outliers found!!")
else:
    for i in outliers_in_freedom_2016:
        print(i)

# Checking for Outliers in Trust (Government Corruption) 2016
trust_list_2016 = d2["Trust (Government Corruption)"].tolist()
Q1 = np.percentile(trust_list_2016, 25)
Q3 = np.percentile(trust_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_trust_2016 = [i for i in trust_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Trust (Government Corruption)' for 2016:")
if len(outliers_in_trust_2016) == 0:
    print("                                             No outliers found!!")
else:
    for i in outliers_in_trust_2016:
        print(i)

# Checking for Outliers in Generosity 2016
generosity_list_2016 = d2["Generosity"].tolist()
Q1 = np.percentile(generosity_list_2016, 25)
Q3 = np.percentile(generosity_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_generosity_2016 = [i for i in generosity_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Generosity' for 2016:")
if len(outliers_in_generosity_2016) == 0:
    print("                                               No outliers found!!")
else:
    for i in outliers_in_generosity_2016:
        print(i)

# Checking for Outliers in Dystopia Residual 2016
dystopia_residual_list_2016 = d2["Dystopia Residual"].tolist()
Q1 = np.percentile(dystopia_residual_list_2016, 25)
Q3 = np.percentile(dystopia_residual_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_dystopia_residual_2016 = [i for i in dystopia_residual_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Dystopia Residual' for 2016:")
if len(outliers_in_dystopia_residual_2016) == 0:
    print("                                               No outliers found!!")
else:
    for i in outliers_in_dystopia_residual_2016:
        print(i)
import numpy as np

# Checking for Outliers in Lower Confidence Interval 2016
lower_ci_list_2016 = d2["Lower Confidence Interval"].tolist()
Q1 = np.percentile(lower_ci_list_2016, 25)
Q3 = np.percentile(lower_ci_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_lower_ci_2016 = [i for i in lower_ci_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Lower Confidence Interval' for 2016:")
if len(outliers_in_lower_ci_2016) == 0:
    print("                                                No outliers found!!")
else:
    for i in outliers_in_lower_ci_2016:
        print(i)

# Checking for Outliers in Upper Confidence Interval 2016
upper_ci_list_2016 = d2["Upper Confidence Interval"].tolist()
Q1 = np.percentile(upper_ci_list_2016, 25)
Q3 = np.percentile(upper_ci_list_2016, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_upper_ci_2016 = [i for i in upper_ci_list_2016 if (i < lower_bound) or (i > upper_bound)]
print("Outliers in 'Upper Confidence Interval' for 2016:")
if len(outliers_in_upper_ci_2016) == 0:
    print("                                                  No outliers found!!")
else:
    for i in outliers_in_upper_ci_2016:
        print(i)
#############################################################################################################2017############################################################3


print(" \n\n                                               OUTLIERS IN 2017                                                   \n\n")
import numpy as np
# Happiness.Rank
happiness_rank_2017 = d3["Happiness.Rank"].tolist()
print("\nHappiness.Rank\n")
Q1 = np.percentile(happiness_rank_2017, 25)
Q3 = np.percentile(happiness_rank_2017, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_in_happiness_rank_2017 = []
for rank in happiness_rank_2017:
    if rank < lower_bound or rank > upper_bound:
        outliers_in_happiness_rank_2017.append(rank)
if len(outliers_in_happiness_rank_2017) == 0:
    print("No outliers found in 'Happiness.Rank'.")
else:
    print("Outliers in the 'Happiness.Rank' column:")
    for rank in outliers_in_happiness_rank_2017:
        print(rank)

# Happiness.Score
happiness_score_2017 = d3["Happiness.Score"].tolist()
print("\nHappiness.Score\n")
Q1 = np.percentile(happiness_score_2017, 25)
Q3 = np.percentile(happiness_score_2017, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_in_happiness_score_2017 = []
for score in happiness_score_2017:
    if score < lower_bound or score > upper_bound:
        outliers_in_happiness_score_2017.append(score)
if len(outliers_in_happiness_score_2017) == 0:
    print("No outliers found in 'Happiness.Score'.")
else:
    print("Outliers in the 'Happiness.Score' column:")
    for score in outliers_in_happiness_score_2017:
        print(score)

# Whisker.high
whisker_high_2017 = d3["Whisker.high"].tolist()
print("\nWhisker.high\n")
Q1 = np.percentile(whisker_high_2017, 25)
Q3 = np.percentile(whisker_high_2017, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_in_whisker_high_2017 = []
for high in whisker_high_2017:
    if high < lower_bound or high > upper_bound:
        outliers_in_whisker_high_2017.append(high)
if len(outliers_in_whisker_high_2017) == 0:
    print("No outliers found in 'Whisker.high'.")
else:
    print("Outliers in the 'Whisker.high' column:")
    for high in outliers_in_whisker_high_2017:
        print(high)

# Whisker.low
whisker_low_2017 = d3["Whisker.low"].tolist()
print("\nWhisker.low\n")
Q1 = np.percentile(whisker_low_2017, 25)
Q3 = np.percentile(whisker_low_2017, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_in_whisker_low_2017 = []
for low in whisker_low_2017:
    if low < lower_bound or low > upper_bound:
        outliers_in_whisker_low_2017.append(low)
if len(outliers_in_whisker_low_2017) == 0:
    print("No outliers found in 'Whisker.low'.")
else:
    print("Outliers in the 'Whisker.low' column:")
    for low in outliers_in_whisker_low_2017:
        print(low)

# Economy..GDP.per.Capita

# Family
family_2017 = d3["Family"].tolist()
print("\nFamily\n")
Q1 = np.percentile(family_2017, 25)
Q3 = np.percentile(family_2017, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_in_family_2017 = []
for family in family_2017:
    if family < lower_bound or family > upper_bound:
        outliers_in_family_2017.append(family)
if len(outliers_in_family_2017) == 0:
    print("No outliers found in 'Family'.")
else:
    print("Outliers in the 'Family' column:")
    for family in outliers_in_family_2017:
        print(family)

health_life_expectancy_2017 = d3["Health..Life.Expectancy."].tolist()
print("\nHealth..Life.Expectancy.)\n")

Q1 = np.percentile(health_life_expectancy_2017, 25)
Q3 = np.percentile(health_life_expectancy_2017, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_health_life_expectancy_2017 = []

for health in health_life_expectancy_2017:
    if health < lower_bound or health > upper_bound:
        outliers_in_health_life_expectancy_2017.append(health)

if len(outliers_in_health_life_expectancy_2017) == 0:
    print("No outliers found in.")
else:
    print("Outliers in the 'Health..Life.Expectancy.'")
    for health in outliers_in_health_life_expectancy_2017:
        print(health)

dystopia_residual_2017 = d3["Dystopia.Residual"].tolist()
print("\nDystopia.Residual\n")

Q1 = np.percentile(dystopia_residual_2017, 25)
Q3 = np.percentile(dystopia_residual_2017, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_dystopia_residual_2017 = []

for residual in dystopia_residual_2017:
    if residual < lower_bound or residual > upper_bound:
        outliers_in_dystopia_residual_2017.append(residual)

if len(outliers_in_dystopia_residual_2017) == 0:
    print("No outliers found in 'Dystopia.Residual'.")
else:
    print("Outliers in the 'Dystopia.Residual' column:")
    for residual in outliers_in_dystopia_residual_2017:
        print(residual)

trust_corruption_2017 = d3["Trust..Government.Corruption."].tolist()
print("\nTrust..Government.Corruption.\n")

Q1 = np.percentile(trust_corruption_2017, 25)
Q3 = np.percentile(trust_corruption_2017, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_trust_corruption_2017 = []

for corruption in trust_corruption_2017:
    if corruption < lower_bound or corruption > upper_bound:
        outliers_in_trust_corruption_2017.append(corruption)

if len(outliers_in_trust_corruption_2017) == 0:
    print("No outliers found in 'Trust..Government.Corruption.'.")
else:
    print("Outliers in the 'Trust..Government.Corruption' column:")
    for corruption in outliers_in_trust_corruption_2017:
        print(corruption)

generosity_2017 = d3["Generosity"].tolist()
print("\nGenerosity\n")

Q1 = np.percentile(generosity_2017, 25)
Q3 = np.percentile(generosity_2017, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_generosity_2017 = []

for generosity in generosity_2017:
    if generosity < lower_bound or generosity > upper_bound:
        outliers_in_generosity_2017.append(generosity)

if len(outliers_in_generosity_2017) == 0:
    print("No outliers found in 'Generosity'.")
else:
    print("Outliers in the 'Generosity' column:")
    for generosity in outliers_in_generosity_2017:
        print(generosity)
freedom_2017 = d3["Freedom"].tolist()
print("\nFreedom\n")

Q1 = np.percentile(freedom_2017, 25)
Q3 = np.percentile(freedom_2017, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_freedom_2017 = []

for freedom in freedom_2017:
    if freedom < lower_bound or freedom > upper_bound:
        outliers_in_freedom_2017.append(freedom)

if len(outliers_in_freedom_2017) == 0:
    print("No outliers found in 'Freedom'.")
else:
    print("Outliers in the 'Freedom' column:")
    for freedom in outliers_in_freedom_2017:
        print(freedom)

economy_gdp_per_capita_2017 = d3["Economy..GDP.per.Capita."].tolist()
print("\nEconomy..GDP.per.Capita.\n")

Q1 = np.percentile(economy_gdp_per_capita_2017, 25)
Q3 = np.percentile(economy_gdp_per_capita_2017, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_economy_gdp_per_capita_2017 = []
for gdp in economy_gdp_per_capita_2017:
    if gdp < lower_bound or gdp > upper_bound:
        outliers_in_economy_gdp_per_capita_2017.append(gdp)

if len(outliers_in_economy_gdp_per_capita_2017) == 0:
    print("No outliers found in 'Economy..GDP.per.Capita.'.")
else:
    print("Outliers in the 'Economy..GDP.per.Capita' column:")
    for gdp in outliers_in_economy_gdp_per_capita_2017:
        print(gdp)

        ###############################################################################2018##########################33##################################
print(" \n\n                                                             OUTLIERS IN 2018                                                    \n\n   ")
overall_rank_2018 = d4["Overall rank"].tolist()
print("\nOverall rank: \n")

Q1 = np.percentile(overall_rank_2018, 25)
Q3 = np.percentile(overall_rank_2018, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_overall_rank_2018 = []

for rank in overall_rank_2018:
    if rank < lower_bound or rank > upper_bound:
        outliers_in_overall_rank_2018.append(rank)

if len(outliers_in_overall_rank_2018) == 0:
    print("No outliers found in 'Overall rank' for 2018.")
else:
    print("Outliers in the 'Overall rank' column for 2018:")
    for rank in outliers_in_overall_rank_2018:
        print(rank)
##########################################################################
#overall_rank_2018 = d4["Country or region"].tolist()
#print("\nCountry or region in 2018\n")
#
#Q1 = np.percentile(country_region_2018, 25)
#Q3 = np.percentile(country_region_2018, 75)
#IQR = Q3 - Q1
#
#lower_bound = Q1 - 1.5 * IQR
#upper_bound = Q3 + 1.5 * IQR
#
#outliers_in_country_region_2018 = []
#
#for rank in country_region_2018:
#    if rank < lower_bound or rank > upper_bound:
#        outliers_in_country_region_2018.append(rank)
#
#if len(outliers_in_country_region_2018) == 0:
#    print("No outliers found in 'Country or region' for 2018.")
#else:
#    print("Outliers in the 'Country or region' column for 2018:")
#    for rank in outliers_in_country_region_2018:
#        print(rank)

score_2018 = d4["Score"].tolist()
print("\nScore: \n")

Q1 = np.percentile(score_2018, 25)
Q3 = np.percentile(score_2018, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_score_2018 = []

for score in score_2018:
    if score < lower_bound or score > upper_bound:
        outliers_in_score_2018.append(score)

if len(outliers_in_score_2018) == 0:
    print("No outliers found in 'Score' for 2018.")
else:
    print("Outliers in the 'Score' column for 2018:")
    for score in outliers_in_score_2018:
        print(score)

gdp_per_capita_2018 = d4["GDP per capita"].tolist()
print("\nGDP per capita :\n")

Q1 = np.percentile(gdp_per_capita_2018, 25)
Q3 = np.percentile(gdp_per_capita_2018, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_gdp_per_capita_2018 = []

for gdp in gdp_per_capita_2018:
    if gdp < lower_bound or gdp > upper_bound:
        outliers_in_gdp_per_capita_2018.append(gdp)

if len(outliers_in_gdp_per_capita_2018) == 0:
    print("No outliers found in 'GDP per capita' for 2018.")
else:
    print("Outliers in the 'GDP per capita' column for 2018:")
    for gdp in outliers_in_gdp_per_capita_2018:
        print(gdp)
social_support_2018 = d4["Social support"].tolist()
print("\nSocial support:\n")

Q1 = np.percentile(social_support_2018, 25)
Q3 = np.percentile(social_support_2018, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_social_support_2018 = []

for support in social_support_2018:
    if support < lower_bound or support > upper_bound:
        outliers_in_social_support_2018.append(support)

if len(outliers_in_social_support_2018) == 0:
    print("No outliers found in 'Social support' for 2018.")
else:
    print("Outliers in the 'Social support' column for 2018:")
    for support in outliers_in_social_support_2018:
        print(support)
healthy_life_expectancy_2018 = d4["Healthy life expectancy"].tolist()
print("\nHealthy life expectancy in 2018\n")

Q1 = np.percentile(healthy_life_expectancy_2018, 25)
Q3 = np.percentile(healthy_life_expectancy_2018, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_healthy_life_expectancy_2018 = []

for expectancy in healthy_life_expectancy_2018:
    if expectancy < lower_bound or expectancy > upper_bound:
        outliers_in_healthy_life_expectancy_2018.append(expectancy)

if len(outliers_in_healthy_life_expectancy_2018) == 0:
    print("No outliers found in 'Healthy life expectancy' for 2018.")
else:
    print("Outliers in the 'Healthy life expectancy' column for 2018:")
    for expectancy in outliers_in_healthy_life_expectancy_2018:
        print(expectancy)

freedom_to_make_choices_2018 = d4["Freedom to make life choices"].tolist()
print("\nFreedom to make life choices in 2018\n")

Q1 = np.percentile(freedom_to_make_choices_2018, 25)
Q3 = np.percentile(freedom_to_make_choices_2018, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_freedom_2018 = []

for freedom in freedom_to_make_choices_2018:
    if freedom < lower_bound or freedom > upper_bound:
        outliers_in_freedom_2018.append(freedom)

if len(outliers_in_freedom_2018) == 0:
    print("No outliers found in 'Freedom to make life choices' for 2018.")
else:
    print("Outliers in the 'Freedom to make life choices' column for 2018:")
    for freedom in outliers_in_freedom_2018:
        print(freedom)
generosity_2018 = d4["Generosity"].tolist()
print("\nGenerosity \n")

Q1 = np.percentile(generosity_2018, 25)
Q3 = np.percentile(generosity_2018, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_generosity_2018 = []

for generosity in generosity_2018:
    if generosity < lower_bound or generosity > upper_bound:
        outliers_in_generosity_2018.append(generosity)

if len(outliers_in_generosity_2018) == 0:
    print("No outliers found in 'Generosity' for 2018.")
else:
    print("Outliers in the 'Generosity' column for 2018:")
    for generosity in outliers_in_generosity_2018:
        print(generosity)
corruption_perceptions_2018 = d4["Perceptions of corruption"].tolist()
print("\nPerceptions of corruption in 2018\n")

Q1 = np.percentile(corruption_perceptions_2018, 25)
Q3 = np.percentile(corruption_perceptions_2018, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_corruption_perceptions_2018 = []

for corruption in corruption_perceptions_2018:
    if corruption < lower_bound or corruption > upper_bound:
        outliers_in_corruption_perceptions_2018.append(corruption)

if len(outliers_in_corruption_perceptions_2018) == 0:
    print("No outliers found in 'Perceptions of corruption' for 2018.")
else:
    print("Outliers in the 'Perceptions of corruption' column for 2018:")
    for corruption in outliers_in_corruption_perceptions_2018:
        print(corruption)

        ########################################################################################2019##########################################################
print(" \n\n                                                                OUTLIERS IN 2019\n")

overall_rank_2019 = d4["Overall rank"].tolist()
print("\nOverall rank\n")

Q1 = np.percentile(overall_rank_2019, 25)
Q3 = np.percentile(overall_rank_2019, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_overall_rank_2019 = []

for rank in overall_rank_2019:
    if rank < lower_bound or rank > upper_bound:
        outliers_in_overall_rank_2019.append(rank)

if len(outliers_in_overall_rank_2019) == 0:
    print("No outliers found in 'Overall rank' for 2019.")
else:
    print("Outliers in the 'Overall rank' column for 2019:")
    for rank in outliers_in_overall_rank_2019:
        print(rank)
################################
print(" \n\nOUTLIERS IN 2019\n")

score_2019 = d4["Score"].tolist()
print("\nScore \n")

Q1 = np.percentile(score_2019, 25)
Q3 = np.percentile(score_2019, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_score_2019 = []

for score in score_2019:
    if score < lower_bound or score > upper_bound:
        outliers_in_score_2019.append(score)

if len(outliers_in_score_2019) == 0:
    print("No outliers found in 'Score' for 2019.")
else:
    print("Outliers in the 'Score' column for 2019:")
    for score in outliers_in_score_2019:
        print(score)
######################################
gdp_per_capita_2019 = d4["GDP per capita"].tolist()
print("\nGDP per capita \n")

Q1 = np.percentile(gdp_per_capita_2019, 25)
Q3 = np.percentile(gdp_per_capita_2019, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_gdp_per_capita_2019 = []

for gdp in gdp_per_capita_2019:
    if gdp < lower_bound or gdp > upper_bound:
        outliers_in_gdp_per_capita_2019.append(gdp)

if len(outliers_in_gdp_per_capita_2019) == 0:
    print("No outliers found in 'GDP per capita' for 2019.")
else:
    print("Outliers in the 'GDP per capita' column for 2019:")
    for gdp in outliers_in_gdp_per_capita_2019:
        print(gdp)
################################################
social_support_2019 = d4["Social support"].tolist()
print("\nSocial support in 2019\n")

Q1 = np.percentile(social_support_2019, 25)
Q3 = np.percentile(social_support_2019, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_social_support_2019 = []

for support in social_support_2019:
    if support < lower_bound or support > upper_bound:
        outliers_in_social_support_2019.append(support)

if len(outliers_in_social_support_2019) == 0:
    print("No outliers found in 'Social support' for 2019.")
else:
    print("Outliers in the 'Social support' column for 2019:")
    for support in outliers_in_social_support_2019:
        print(support)
####################################################
health_life_expectancy_2019 = d4["Healthy life expectancy"].tolist()
print("\nHealthy life expectancy in 2019\n")

Q1 = np.percentile(health_life_expectancy_2019, 25)
Q3 = np.percentile(health_life_expectancy_2019, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_health_life_expectancy_2019 = []

for health in health_life_expectancy_2019:
    if health < lower_bound or health > upper_bound:
        outliers_in_health_life_expectancy_2019.append(health)

if len(outliers_in_health_life_expectancy_2019) == 0:
    print("No outliers found in 'Healthy life expectancy' for 2019.")
else:
    print("Outliers in the 'Healthy life expectancy' column for 2019:")
    for health in outliers_in_health_life_expectancy_2019:
        print(health)
############################################################
freedom_2019 = d4["Freedom to make life choices"].tolist()
print("\nFreedom to make life choices in 2019\n")

Q1 = np.percentile(freedom_2019, 25)
Q3 = np.percentile(freedom_2019, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_freedom_2019 = []

for freedom in freedom_2019:
    if freedom < lower_bound or freedom > upper_bound:
        outliers_in_freedom_2019.append(freedom)

if len(outliers_in_freedom_2019) == 0:
    print("No outliers found in 'Freedom to make life choices' for 2019.")
else:
    print("Outliers in the 'Freedom to make life choices' column for 2019:")
    for freedom in outliers_in_freedom_2019:
        print(freedom)
########################################################
freedom_2019 = d4["Freedom to make life choices"].tolist()
print("\nFreedom to make life choices\n")

Q1 = np.percentile(freedom_2019, 25)
Q3 = np.percentile(freedom_2019, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_freedom_2019 = []

for freedom in freedom_2019:
    if freedom < lower_bound or freedom > upper_bound:
        outliers_in_freedom_2019.append(freedom)

if len(outliers_in_freedom_2019) == 0:
    print("No outliers found in 'Freedom to make life choices' for 2019.")
else:
    print("Outliers in the 'Freedom to make life choices' column for 2019:")
    for freedom in outliers_in_freedom_2019:
        print(freedom)
################################################################
generosity_2019 = d4["Generosity"].tolist()
print("\nGenerosityn")

Q1 = np.percentile(generosity_2019, 25)
Q3 = np.percentile(generosity_2019, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_generosity_2019 = []

for generosity in generosity_2019:
    if generosity < lower_bound or generosity > upper_bound:
        outliers_in_generosity_2019.append(generosity)

if len(outliers_in_generosity_2019) == 0:
    print("No outliers found in 'Generosity'.")
else:
    print("Outliers in the 'Generosity':")
    for generosity in outliers_in_generosity_2019:
        print(generosity)
################################################################
corruption_2019 = d4["Perceptions of corruption"].tolist()
print("\nPerceptions of corruption: \n")

Q1 = np.percentile(corruption_2019, 25)
Q3 = np.percentile(corruption_2019, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_in_corruption_2019 = []

for corruption in corruption_2019:
    if corruption < lower_bound or corruption > upper_bound:
        outliers_in_corruption_2019.append(corruption)

if len(outliers_in_corruption_2019) == 0:
    print("No outliers found  .")
else:
    print("Outliers in the 'Perceptions of corruption' :")
    for corruption in outliers_in_corruption_2019:
        print(corruption)
#######################################################################################################################################
                                                     #CELL 2
import matplotlib.pyplot as plt
import pandas as pd

# Select the columns of interest
x = d2["Economy (GDP per Capita)"]
y = d2["Happiness Score"]

# Create a scatter plot
plt.figure(figsize=(15,5))
#plt.scatter(x, y, alpha=0.5)  # Adjust the alpha value for transparency
plt.scatter(x, y, c='blue', marker='*', edgecolors='black', alpha=0.6, s=80)
plt.title('Scatter Plot: Happiness Score vs Economy (GDP per Capita)')
plt.xlabel('Economy (GDP per Capita)')
plt.ylabel('Happiness Score')
plt.grid(True)  # Add grid lines if desired
plt.show()
#######################################################################################################################################
                                                     #CELL 3

data_sets = [d1, d2, d3, d4, d5]
years = [2015, 2016, 2017, 2018, 2019]
for i in range(len(data_sets)):
    data_sets[i]['Year'] = years[i]
for k in data_sets:
    k.rename(columns={'Happiness Score': 'Happiness-Score', 'Happiness.Score': 'Happiness-Score', 'Country or region': 'Country', 'Score': 'Happiness-Score'}, inplace=True)
result = pd.concat(data_sets, ignore_index=True)
result['Region'] = result.apply(lambda row: row['Country'] if row['Year'] in [2017, 2018, 2019] else row['Region'], axis=1)
result = result.pivot_table(index=['Country', 'Region'], columns='Year', values='Happiness-Score').reset_index()
result.columns = ['Country', 'Region', '2015', '2016', '2017', '2018', '2019']
result.to_csv('laiba.csv', index=False)
#######################################################################################################################################
                                                     #CELL 4
import pandas as pd
import matplotlib.pyplot as plt
# Load the DataFrame (replace 'combined_happiness.csv' with the actual filename)
to_plot_data_frame = pd.read_csv('laiba.csv')
# Choose two countries for the line chart
country1 = 'United States'  # Replace with your first country
country2 = 'Germany'          # Replace with your second country
# Filter the DataFrame for the selected countries
country1_plot_data_frame = to_plot_data_frame[to_plot_data_frame['Country'] == country1]
country2_plot_data_frame = to_plot_data_frame[to_plot_data_frame['Country'] == country2]
# Extract the years and Happiness Score values
X_axis = to_plot_data_frame.columns[2:]  # Assuming columns 2 onward contain the years
happiness_scores_country1 = country1_plot_data_frame.iloc[0, 2:].values
happiness_scores_country2 = country2_plot_data_frame.iloc[0, 2:].values
# Create a line chart with a white background
plt.figure(figsize=(11, 5))
plt.plot(X_axis, happiness_scores_country1, marker='*', label=country1)
plt.plot(X_axis, happiness_scores_country2, marker='p', label=country2)
plt.title('Happiness Score Trends in Years', fontsize=14)
plt.xlabel('Year', fontsize=13)
plt.ylabel('Happiness Score', fontsize=13)
plt.legend()
plt.grid(True, linestyle='-', alpha=0.7)
plt.gca().set_facecolor('black')
plt.show()

#######################################################################################################################################
                                                     #CELL 5
import pandas as pd

# Load your dataset into a DataFrame (replace '2015.csv' with the actual filename)
d7 = pd.read_csv("2015.csv")
list11=d7.loc[d7['Economy (GDP per Capita)']<0.5, 'Region'].tolist()
#print(list11)
unique_list11 = list(set(list11))
# Print the unique list
print(unique_list11)

#######################################################################################################################################
                                                     #CELL 6
import pandas as pd

# Load the dataset for the year 2015 (replace with your actual data file)
import pandas as pd

data_2015 = pd.read_csv('2015.csv')

selected_column = 'Happiness Rank'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value1 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value1}.")

selected_column = 'Happiness Score'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value2 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value2}.")

selected_column = 'Standard Error'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value3 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value3}.")

selected_column = 'Family'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value4 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value4}.")

selected_column = 'Freedom'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value5 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value5}.")

selected_column = 'Generosity'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value6 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value6}.")

selected_column = 'Dystopia Residual'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value7 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value7}.")

selected_column = 'Economy (GDP per Capita)'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value8 = correlations.drop(selected_column).max()
#print(f"The column with highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value8}.")

selected_column = 'Health (Life Expectancy)'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value9 = correlations.drop(selected_column).max()
#print(f"The column with highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value9}.")

selected_column = 'Trust (Government Corruption)'
correlations = data_2015.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value10 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value10}.")

my_list=[max_corr_value1, max_corr_value2, max_corr_value3, max_corr_value4, max_corr_value5, max_corr_value6, max_corr_value7, max_corr_value8, max_corr_value9, max_corr_value10]
max_value = my_list[0]
for item in my_list:
    if item > max_value:
        max_value = item
print("The maximum correlation in the dataset 2015 is between Economy(GDP per Capita) and Health (Life Expectancy) ", max_value)

###################################################################################################2016####################################################################

data_2016 = pd.read_csv('2016.csv')

selected_column = 'Happiness Rank'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value1 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value1}.")

selected_column = 'Happiness Score'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value2 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value2}.")

selected_column = 'Upper Confidence Interval'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value3 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value3}.")

selected_column = 'Family'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value4 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value4}.")

selected_column = 'Freedom'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value5 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value5}.")

selected_column = 'Generosity'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value6 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value6}.")

selected_column = 'Dystopia Residual'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value7 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value7}.")

selected_column = 'Economy (GDP per Capita)'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value8 = correlations.drop(selected_column).max()
#print(f"The column with highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value8}.")

selected_column = 'Health (Life Expectancy)'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value9 = correlations.drop(selected_column).max()
#print(f"The column with highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value9}.")

selected_column = 'Trust (Government Corruption)'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value10 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value10}.")

selected_column = 'Lower Confidence Interval'
correlations = data_2016.corr()[selected_column]
max_corr_column = correlations.drop(selected_column).idxmax()
max_corr_value11 = correlations.drop(selected_column).max()
#print(f"The column with the highest correlation to '{selected_column}' is '{max_corr_column}' with a correlation of {max_corr_value3}.")

my_list = [max_corr_value1, max_corr_value2, max_corr_value3, max_corr_value4, max_corr_value5, max_corr_value6, max_corr_value7, max_corr_value8, max_corr_value9, max_corr_value10,max_corr_value11]
max_value = my_list[0]
for item in my_list:
    if item > max_value:
        max_value = item
print("The maximum correlation in the dataset 2016 is between Economy(GDP per Capita) and Health (Life Expectancy) ", max_value)
# Out:
#  The values that range from 0.5 to 1 from Health (Life Expectancy):
#
#
# ...

# %%
#### print("\n------------------------------------------------------------------------\n")
print("                                MISSING VALUES (PART A)                        ")
import numpy as np
import pandas as pd
import seaborn as sns
earth = pd.read_csv("earth_surface_temperatures.csv")
missed= earth.isnull().sum()
earth.dropna().to_csv("LALA.csv", index=False)
print("Missing values after cleaning:")
print(earth.isnull().sum())
############################################################################
print("\n------------------------------------------------------------------------\n")
print("                                   DATA TYPES (PART B)                        ")
typee =me.dtypes
print(" DATA TYPES: ")
print(typee)
print("\n")
me["Years"] = pd.to_datetime(me["Years"])
me["Month"] = pd.to_datetime(me["Month"])
me["Country"] = me["Country"].astype("category")
typesss = me.dtypes
print("DATA TYPES : ")
print(typesss)
print("\n")
#############################################################################
print("\n------------------------------------------------------------------------\n")
print("                                     DATE (PART C)                        ")
print("\n\n")
me['Date'] = me['Month'].astype(str) + '-' + me['Years'].astype(str)
#me['Date'] = me.apply(lambda row: f"{row['Month']}-{row['Years']}", axis=1)
print("The data frame's date column will look like: \n")
print(me)
#############################################################################
print("\n------------------------------------------------------------------------\n")
print("                          Checking for OUTLIERS in Temperature  (PART D)                        ")
temperature_list = me["Temperature"].tolist()
Q1 = np.percentile(temperature_list, 25)
Q3 = np.percentile(temperature_list, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_in_temperature = []
for temperature in temperature_list:
    if (temperature < lower_bound) or (temperature > upper_bound):
        outliers_in_temperature.append(temperature)

if len(outliers_in_temperature) == 0:
    print("No outliers found in the Temperature column.")
else:
    print("Outliers in Temperature:")
    for temperature in outliers_in_temperature:
        print(temperature)
###################################################################
print("                                 SUMMARY STATISTICS  PART(E)                   \n")
print("                      TEMPERATURE:                               \n")
mean_t = me['Temperature'].mean()
median_t = me['Temperature'].median()
sd_t = me['Temperature'].std()
maxi= me['Temperature'].max()
mini= me['Temperature'].min()
rng_t=maxi-mini
# Print the results
print("The mean value of the temperature is : ")
print(mean_t)
print("\n\n")
print("The mmedian value of the temperature is : ")
print(median_t)
print("\n\n")
print("The standard deviation value of the temperature is :")
print(sd_t)
print("\n\n")
print("The range value of the temperature is : ")
print(rng_t)
print("\n\n")
print("                     MONTHLY VARIATION:                               \n")
mean_mon_var = me['Monthly_variation'].mean()
median_mon_var = me['Monthly_variation'].median()
sd_mon_var= me['Monthly_variation'].std()
maxi_mon_var= me['Monthly_variation'].max()
mini_mon_var= me['Monthly_variation'].min()
rng_mon_var=maxi_mon_var-mini_mon_var
# Print the results
print("The mean value of the Monthly variation is : ")
print(mean_mon_var)
print("\n\n")
print("The mmedian value of the  Monthly variation is : ")
print(median_mon_var)
print("\n\n")
print("The standard deviation value of the  Monthly variation is :")
print(sd_mon_var)
print("\n\n")
print("The range value of the  Monthly variation is : ")
print(rng_mon_var)
print("\n\n")
print("                    ANOMLAY VALUES:                               \n")
mean_anom_val = me['Anomaly'].mean()
median_anom_val = me['Anomaly'].median()
sd_anom_val= me['Anomaly'].std()
maxi_anom_val= me['Anomaly'].max()
mini_anom_val= me['Anomaly'].min()
rng_anom_val=maxi_anom_val-mini_anom_val
print("The mean value of the Anomaly values is : ")
print(mean_anom_val)
print("\n\n")
print("The mmedian value of the Anomaly values is : ")
print(median_anom_val)
print("\n\n")
print("The standard deviation value of the Anomaly values is :")
print(sd_anom_val)
print("\n\n")
print("The range value of the Anomaly values variationis : ")
print(rng_anom_val)
print("\n\n")
###############################################################################################
print("\n------------------------------------------------------------------------\n")
print("                        AVERAGE TEMPERATURE VALUES  PART(F)                       ")
print("\n\n")
me = pd.read_csv("LALA.csv")
print("\n\n")
avg_value_of_temp = me.groupby('Country')['Temperature'].mean()
print(avg_value_of_temp)
##############################################################################
print("\n------------------------------------------------------------------------\n")
print("                       GLOBAL TRENDS OVER TEMPERATURES (PART G)          " )
TREND = me.groupby('Years')['Temperature'].mean()
plt.figure(figsize=(13, 7))
plt.plot(TREND.index, TREND.values,color='black', label='Global Temperature Trend')
plt.title("Global Temperature Trend Over the Years")
plt.xlabel("Years")
plt.ylabel("Temperature")

plt.grid(True)
plt.show()

#######################################################################################

print("\n------------------------------------------------------------------------\n")
print("                      FIVE COUNTRIES TREND (PART J)"                          )

count = ['Afghanistan', 'Iceland', 'Libya', 'Samoa', 'Spain']
CHOICE = me[me['Country'].isin(count)]
plt.figure(figsize=(12, 6))
for country in count:
    values = CHOICE[CHOICE['Country'] == country]
    plt.plot(values['Years'], values['Temperature'], label=country)
#PLOTTING
plt.ylabel("Temperature")
plt.title("Temperature Trends in Selected Countries")
plt.xlabel("Year")
plt.show()

print("\n------------------------------------------------------------------------\n")
print("                      FIVE COUNTRIES TREND (PART k)"                          )

COLOR= 'black'
c1 = 'Monthly_variation'
c2 = 'Temperature'
cor = me[c1].corr(me[c2])
print(f"Correlation between {c1} and {c2}: {cor:.2f}")
plt.figure(figsize=(12, 7))
plt.scatter(me[c1] , me[c2], alpha=1)
plt.title(f"PLOTTING: {c1} vs {c2}")
plt.ylabel(c2)
plt.gca().set_facecolor(COLOR)
plt.xlabel(c1)
plt.show()
